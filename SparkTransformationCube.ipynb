# %%
# exercise to show transformation of map()
inData = sc.parallelize([1,2,3,4,5])

#the function takes input number and finds the cube of the number
outData = inData.map(lambda x: x*x*x).collect()

#printing the output data set
for x in outData:
  print (x)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1
# 8
# 27
# 64
# 125
# </div>
