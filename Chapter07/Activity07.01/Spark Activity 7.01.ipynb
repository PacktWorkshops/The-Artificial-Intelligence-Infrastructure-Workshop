# %%
# File location and type
file_location = "/FileStore/tables/Film_Locations_in_San_Francisco.csv"
file_type = "csv"

# CSV options
infer_schema = "false"
first_row_is_header = "true"
delimiter = ","

# The applied options are for CSV files. For other file types, these will be ignored.
dataTable = spark.read.format(file_type) \
  .option("inferSchema", infer_schema) \
  .option("header", first_row_is_header) \
  .option("sep", delimiter) \
  .load(file_location)

display(dataTable)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# Create a view or table
temp_table_name = "Film_Locations_in_San_Francisco_New"
dataTable.createOrReplaceTempView(temp_table_name)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
/* Query the created temp table in a SQL cell */
select * from `Film_Locations_in_San_Francisco_New`
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
inData = dataTable.rdd.map(list)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
inData.collect()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: [[&#39;180&#39;,
#   &#39;2011&#39;,
#   &#39;Epic Roasthouse (399 Embarcadero)&#39;,
#   None,
#   &#39;SPI Cinemas&#39;,
#   None,
#   &#39;Jayendra&#39;,
#   &#39;Umarji Anuradha, Jayendra, Aarthi Sriram, &amp; Suba &#39;,
#   &#39;Siddarth&#39;,
#   &#39;Nithya Menon&#39;,
#   &#39;Priya Anand&#39;],
#  [&#39;180&#39;,
#   &#39;2011&#39;,
#   &#39;Mason &amp; California Streets (Nob Hill)&#39;,
#   None,
#   &#39;SPI Cinemas&#39;,
#   None,
#   &#39;Jayendra&#39;,
#   &#39;Umarji Anuradha, Jayendra, Aarthi Sriram, &amp; Suba &#39;,
#   &#39;Siddarth&#39;,
#   &#39;Nithya Menon&#39;,
#   &#39;Priya Anand&#39;],
# ...

# %%
inData.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[8]: 3463</div>

# %%
inData.first()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[9]: [&#39;180&#39;,
#  &#39;2011&#39;,
#  &#39;Epic Roasthouse (399 Embarcadero)&#39;,
#  None,
#  &#39;SPI Cinemas&#39;,
#  None,
#  &#39;Jayendra&#39;,
#  &#39;Umarji Anuradha, Jayendra, Aarthi Sriram, &amp; Suba &#39;,
#  &#39;Siddarth&#39;,
#  &#39;Nithya Menon&#39;,
#  &#39;Priya Anand&#39;]</div>

# %%
inData.take(3)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[10]: [[&#39;180&#39;,
#   &#39;2011&#39;,
#   &#39;Epic Roasthouse (399 Embarcadero)&#39;,
#   None,
#   &#39;SPI Cinemas&#39;,
#   None,
#   &#39;Jayendra&#39;,
#   &#39;Umarji Anuradha, Jayendra, Aarthi Sriram, &amp; Suba &#39;,
#   &#39;Siddarth&#39;,
#   &#39;Nithya Menon&#39;,
#   &#39;Priya Anand&#39;],
#  [&#39;180&#39;,
#   &#39;2011&#39;,
#   &#39;Mason &amp; California Streets (Nob Hill)&#39;,
#   None,
#   &#39;SPI Cinemas&#39;,
#   None,
#   &#39;Jayendra&#39;,
#   &#39;Umarji Anuradha, Jayendra, Aarthi Sriram, &amp; Suba &#39;,
#   &#39;Siddarth&#39;,
#   &#39;Nithya Menon&#39;,
#   &#39;Priya Anand&#39;],
# ...
